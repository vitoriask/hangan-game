# %% [markdown]
# <a href="https://colab.research.google.com/github/vitria18/hangan-game/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#problema na continuação quando acerta ok
#completando as últimas letras sozinho ok
#problema na passagem do terceiro erro ok
#problema na continuação do loop sim ou não ok
#retornando segundo round com a palavra do primeiro ok
#indo automaticamente para o loop sim ou não ok
#parando no segunda letra certa ok
#não está mais rodando kkkk ok

#avançado:1) trazer lista de nomes por categoria 2) jogar contra o computador


import random
import time
# Initial Steps to invite in the game:
print("\nWelcome to Hangman game by DataFlair\n")
name = input("Enter your name: ")
print("Hello " + name + "! Best of Luck!")
time.sleep(2)
print("The game is about to start!\n Let's play Hangman!")
time.sleep(3)
def main():
    global count
    global display
    global word
    global already_guessed
    global length
    global play_game
    global partida
    words_to_guess = ["january","border","image","film","promise","kids","lungs","doll","rhyme","damage","plants"]
    word = random.choice(words_to_guess)
    length = len(word)
    count = 0
    display = '_' * length
    already_guessed = []
    play_game = " = "
# A loop to re-execute the game when the first round ends:
def play_loop():
    global play_game
    global partida
    partida = 0
    play_game = input("Do You want to play again? y = yes, n = no \n")
    while play_game not in ["y", "n","Y","N"]:
        play_game = input("Do You want to play again? y = yes, n = no \n")
    if play_game == "y":
        partida = partida + 1
        main()
        hangman()
    elif play_game == "n":
        print("Thanks For Playing! We expect you back again!")
        exit()
# Initializing all the conditions required for the game:
def hangman():
    global count
    global display
    global word
    global already_guessed
    global play_game
    global partida
    partida = 0
    limit = 5
    if partida == 0:
        guess = input("This is the Hangman Word: " + display + " Enter your guess: \n")
        guess = guess.strip()
        if len(guess.strip()) == 0 or len(guess.strip()) >= 2 or guess <= "9":
            print("Invalid Input, Try a letter\n")
            hangman()   
               
        elif guess in word:
            already_guessed.extend([guess])
            index = word.find(guess)
            word = word[:index] + "_" + word[index + 1:]
            display = display[:index] + guess + display[index + 1:]
            print(display + "\n")
        elif guess in already_guessed:
            print("Try another letter.\n")
        else:
            count += 1
            if count == 1:
                time.sleep(1)
                print(" _____ \n" " | \n" " | \n" " | \n" " | \n" " | \n" " | \n" "__|__\n")
                print("Wrong guess. " + str(limit - count) + " guesses remaining\n")
            elif count == 2:
                time.sleep(1)
                print(" _____ \n" " | | \n" " | |\n" " | \n" " | \n" " | \n" " | \n" "__|__\n")
                print("Wrong guess. " + str(limit - count) + " guesses remaining\n")
            elif count == 3:
                time.sleep(1)
                print(" _____ \n" " | | \n" " | |\n" " | | \n" " | \n" " | \n" " | \n" "__|__\n")
                print("Wrong guess. " + str(limit - count) + " guesses remaining\n")
            elif count == 4:
                time.sleep(1)
                print(" _____ \n" " | | \n" " | |\n" " | | \n" " | O \n" " | \n" " | \n" "__|__\n")
                print("Wrong guess. " + str(limit - count) + " last guess remaining\n")
            elif count == 5:
                time.sleep(1)
                print(" _____ \n" " | | \n" " | |\n" " | | \n" " | O \n" " | /|\ \n" " | / \ \n" "__|__\n")
                print("Wrong guess. You are hanged!!!\n")
                print("The word was:",already_guessed,word)
                play_loop()
        if word == '_' * length:
             print("Congrats! You have guessed the word correctly!")
             play_loop()
        elif count != limit:
             hangman()
    else:
        main()
        hangman()
        
main()
hangman()
# Out:
# Welcome to Hangman game by DataFlair
#
# Enter your name: v
# Hello v! Best of Luck!
# The game is about to start!
#  Let's play Hangman!
# This is the Hangman Word: ____ Enter your guess:
# i
# _i__
#
# This is the Hangman Word: _i__ Enter your guess:
# k
# ki__
#
# This is the Hangman Word: ki__ Enter your guess:
# d
# kid_
#
# This is the Hangman Word: kid_ Enter your guess:
# s
# kids
#
# Congrats! You have guessed the word correctly!
# Do You want to play again? y = yes, n = no
# y
# This is the Hangman Word: ______ Enter your guess:
# e
#  _____
#  |
#  |
#  |
#  |
#  |
#  |
# __|__
#
# Wrong guess. 4 guesses remaining
#
# This is the Hangman Word: ______ Enter your guess:
# a
# __a___
#
# This is the Hangman Word: __a___ Enter your guess:
# i
#  _____
#  | |
#  | |
#  |
#  |
#  |
#  |
# __|__
#
# Wrong guess. 3 guesses remaining
#
# This is the Hangman Word: __a___ Enter your guess:
# p
# p_a___
#
# This is the Hangman Word: p_a___ Enter your guess:
# l
# pla___
#
# ...
